# %%
2+2
# Out:
# 4

# %%
lis = [lambda x: x**2 for x in range(10)]
lis
# Out:
# [<function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>,
#  <function __main__.<lambda>(x)>]

# %%
lis = ['image_10.png', 'image_1.png', 'image_05.png']

sorted_lis = sorted(lis, key = lambda x: int(x.split('_')[1].split('.')[0]))
sorted_lis
# Out:
# ['image_1.png', 'image_05.png', 'image_10.png']

# %%
import json
with open('patients.json', 'r') as file:
    data = json.load(file)

# %%
data
# Out:
# {'P001': {'name': 'Ananya Sharma',
#   'city': 'Guwahati',
#   'age': 28,
#   'gender': 'female',
#   'height': 1.65,
#   'weight': 90.0,
#   'bmi': 33.06,
#   'verdict': 'Obese'},
#  'P002': {'name': 'Ravi Mehta',
#   'city': 'Mumbai',
#   'age': 35,
#   'gender': 'male',
#   'height': 1.75,
#   'weight': 85,
#   'bmi': 27.76,
#   'verdict': 'Overweight'},
#  'P003': {'name': 'Sneha Kulkarni',
#   'city': 'Pune',
#   'age': 22,
#   'gender': 'female',
#   'height': 1.6,
#   'weight': 45,
#   'bmi': 17.58,
#   'verdict': 'Underweight'},
#  'P004': {'name': 'Arjun Verma',
#   'city': 'Bangalore',
#   'age': 40,
#   'gender': 'male',
#   'height': 1.8,
#   'weight': 95,
#   'bmi': 29.32,
#   'verdict': 'Overweight'},
#  'P005': {'name': 'Neha Sinha',
#   'city': 'Kolkata',
#   'age': 30,
#   'gender': 'female',
#   'height': 1.55,
#   'weight': 75,
#   'bmi': 31.22,
#   'verdict': 'Obese'}}

# %%
data.keys()
# Out:
# dict_keys(['P001', 'P002', 'P003', 'P004', 'P005'])

# %%
for val in data.values():
    print(val)
# Out:
# {'name': 'Ananya Sharma', 'city': 'Guwahati', 'age': 28, 'gender': 'female', 'height': 1.65, 'weight': 90.0, 'bmi': 33.06, 'verdict': 'Obese'}
# {'name': 'Ravi Mehta', 'city': 'Mumbai', 'age': 35, 'gender': 'male', 'height': 1.75, 'weight': 85, 'bmi': 27.76, 'verdict': 'Overweight'}
# {'name': 'Sneha Kulkarni', 'city': 'Pune', 'age': 22, 'gender': 'female', 'height': 1.6, 'weight': 45, 'bmi': 17.58, 'verdict': 'Underweight'}
# {'name': 'Arjun Verma', 'city': 'Bangalore', 'age': 40, 'gender': 'male', 'height': 1.8, 'weight': 95, 'bmi': 29.32, 'verdict': 'Overweight'}
# {'name': 'Neha Sinha', 'city': 'Kolkata', 'age': 30, 'gender': 'female', 'height': 1.55, 'weight': 75, 'bmi': 31.22, 'verdict': 'Obese'}

# %%
import json
def load_data():
    with open('patients.json', 'r') as file:
        data = json.load(file)
    return data
patient_json_data = load_data()

# %%
patient_id_list = [key for key in patient_json_data.keys()]
patient_id_list
# Out:
# ['P001', 'P002', 'P003', 'P004', 'P005']

# %%
patient_json_data['P001']
# Out:
# {'name': 'Ananya Sharma',
#  'city': 'Guwahati',
#  'age': 28,
#  'gender': 'female',
#  'height': 1.65,
#  'weight': 90.0,
#  'bmi': 33.06,
#  'verdict': 'Obese'}

# %%
student = {'name':'Tinon Turja Majumder',
           'Age': 26,
           'Occupation': 'Research Assistant',
           'Salary': 0}

student.get('name')
# Out:
# 'Tinon Turja Majumder'

# %%
student.get('Occupation')
# Out:
# 'Research Assistant'

# %%
data = load_data()

# %%
data.keys()
# Out:
# dict_keys(['P001', 'P002', 'P003', 'P004', 'P005'])

# %%
id_sort = sorted(data.keys(), key = lambda x: int(x.split('P')[1]))
id_sort
# Out:
# ['P001', 'P002', 'P003', 'P004', 'P005']

# %%
type(data.values())
# Out:
# dict_values
